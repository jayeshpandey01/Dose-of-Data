# %% [markdown]
# Let's Do It Mickey

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

pokemon_data = pd.read_csv('pokemon.csv')
pokemon_data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %% [markdown]
# data Collection

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %% [markdown]
# height_m, percentage_male, type2, weight_kg ==> this has missing data

# %%
pokemon_data['height_m'].unique()
# Out:
# array([ 0.7,  1. ,  2. ,  0.6,  1.1,  1.7,  0.5,  1.6,  0.3,  1.5,  nan,
#         1.2,  3.5,  0.4,  0.8,  1.3,  0.9,  1.4,  1.9,  1.8,  8.8,  2.2,
#         6.5,  2.5,  2.1,  4. ,  2.3,  0.2,  9.2,  5.2,  3.8, 14.5,  2.7,
#         6.2,  4.5,  7. ,  2.4,  5.4,  4.2,  3.7,  3.2,  3.3,  0.1,  2.6,
#         2.8,  2.9,  3. ,  5.8,  5. ,  3.9,  3.4,  5.5])

# %%
pokemon_data['height_m'].describe()
# Out:
# count    781.000000
# mean       1.163892
# std        1.080326
# min        0.100000
# 25%        0.600000
# 50%        1.000000
# 75%        1.500000
# max       14.500000
# Name: height_m, dtype: float64

# %%
pokemon_data[pokemon_data['height_m'] > 10]
# Out:
#                                    abilities  against_bug  against_dark  \
# 320  ['Water Veil', 'Oblivious', 'Pressure']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 320             1.0               2.0            1.0            1.0
#
#      against_fire  against_flying  against_ghost  ...  percentage_male  \
# 320           0.5             1.0            1.0  ...             50.0
#
#      pokedex_number  sp_attack  sp_defense  speed  type1  type2  weight_kg  \
# 320             321         90          45     60  water    NaN      398.0
#
#      generation  is_legendary
# 320           3             0
#
# [1 rows x 41 columns]

# %%
pokemon_data['height_m'].isnull().sum()
# Out:
# 20

# %%
pokemon_data.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
px.scatter(
    x = pokemon_data.height_m,
    y = pokemon_data.weight_kg,
    # hue = pokemon_data.height_m,
    # s = 40
)

# %% [markdown]
# 0.1 = 0.1; 0.2 = 3.4; 0.3 = 40; 0.4 = 60; 0.5 = 80.4; 0.6 = 105;

# %%
pokemon_data.dropna(subset=['height_m', 'weight_kg'], inplace=True)

# %%
pokemon_data
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
pokemon_data['percentage_male'].isnull().sum()
# Out:
# 97

# %%
pokemon_data['percentage_male'].unique(), pokemon_data['percentage_male'].describe()
# Out:
# (array([ 88.1,  50. ,   0. , 100. ,  24.6,  75.4,   nan,  11.2]),
#  count    684.000000
#  mean      55.373246
#  std       20.457536
#  min        0.000000
#  25%       50.000000
#  50%       50.000000
#  75%       50.000000
#  max      100.000000
#  Name: percentage_male, dtype: float64)

# %%
pokemon_data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
pokemon_data['percentage_male'].isnull().sum()
# Out:
# 97

# %%
pokemon_data[pokemon_data['percentage_male'] == 0.0]
# Out:
#                                             abilities  against_bug  \
# 28              ['Poison Point', 'Rivalry', 'Hustle']         0.50
# 29              ['Poison Point', 'Rivalry', 'Hustle']         0.50
# 30         ['Poison Point', 'Rivalry', 'Sheer Force']         0.50
# 112        ['Natural Cure', 'Serene Grace', 'Healer']         1.00
# 114          ['Early Bird', 'Scrappy', 'Inner Focus']         1.00
# 123             ['Oblivious', 'Forewarn', 'Dry Skin']         2.00
# 237            ['Oblivious', 'Forewarn', 'Hydration']         2.00
# 240            ['Thick Fat', 'Scrappy', 'Sap Sipper']         1.00
# 241        ['Natural Cure', 'Serene Grace', 'Healer']         1.00
# 313         ['Oblivious', 'Tinted Lens', 'Prankster']         1.00
# 379                                      ['Levitate']         2.00
# 412                      ['Anticipation', 'Overcoat']         2.00
# 415                           ['Pressure', 'Unnerve']         0.50
# ...

# %% [markdown]
# counts = 27

# %%
pokemon_data.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
px.scatter(pokemon_data,
    x = 'percentage_male',
    y = 'weight_kg'
)

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 781 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          781 non-null    object
#  1   against_bug        781 non-null    float64
#  2   against_dark       781 non-null    float64
#  3   against_dragon     781 non-null    float64
#  4   against_electric   781 non-null    float64
#  5   against_fairy      781 non-null    float64
#  6   against_fight      781 non-null    float64
#  7   against_fire       781 non-null    float64
#  8   against_flying     781 non-null    float64
#  9   against_ghost      781 non-null    float64
#  10  against_grass      781 non-null    float64
#  11  against_ground     781 non-null    float64
#  12  against_ice        781 non-null    float64
#  13  against_normal     781 non-null    float64
#  14  against_poison     781 non-null    float64
# ...

# %%
pokemon_data['classfication']
# Out:
# 0             Seed Pokémon
# 1             Seed Pokémon
# 2             Seed Pokémon
# 3           Lizard Pokémon
# 4            Flame Pokémon
#               ...
# 796         Launch Pokémon
# 797    Drawn Sword Pokémon
# 798      Junkivore Pokémon
# 799          Prism Pokémon
# 800     Artificial Pokémon
# Name: classfication, Length: 781, dtype: object

# %%
pokemon_data['Total_Attack'] = pokemon_data['attack'] + pokemon_data['sp_attack']

# %%
pokemon_data['Total_Defense'] = pokemon_data['defense'] + pokemon_data['sp_defense']

# %%
pokemon_data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  sp_attack  sp_defense  speed  type1  \
# ...

# %%
px.scatter(
    pokemon_data,
    x = 'Total_Attack',
    y = 'percentage_male'
)

# %%
pokemon_data[['percentage_male', 'Total_Attack']]
# Out:
#      percentage_male  Total_Attack
# 0               88.1           114
# 1               88.1           142
# 2               88.1           222
# 3               88.1           112
# 4               88.1           144
# ..               ...           ...
# 796              NaN           208
# 797              NaN           240
# 798              NaN           198
# 799              NaN           234
# 800              NaN           225
#
# [781 rows x 2 columns]

# %%
pokemon_data['percentage_male'].unique()
# Out:
# array([ 88.1,  50. ,   0. , 100. ,  24.6,  75.4,   nan,  11.2])

# %%
pokemon_data['type2'].fillna('None', inplace=True)
# Out:
# C:\Users\Jayesh pandey\AppData\Local\Temp\ipykernel_350868\3599200341.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
pokemon_data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  sp_attack  sp_defense  speed  type1  \
# ...

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 781 entries, 0 to 800
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          781 non-null    object
#  1   against_bug        781 non-null    float64
#  2   against_dark       781 non-null    float64
#  3   against_dragon     781 non-null    float64
#  4   against_electric   781 non-null    float64
#  5   against_fairy      781 non-null    float64
#  6   against_fight      781 non-null    float64
#  7   against_fire       781 non-null    float64
#  8   against_flying     781 non-null    float64
#  9   against_ghost      781 non-null    float64
#  10  against_grass      781 non-null    float64
#  11  against_ground     781 non-null    float64
#  12  against_ice        781 non-null    float64
#  13  against_normal     781 non-null    float64
#  14  against_poison     781 non-null    float64
# ...

# %%
pokemon_data['capture_rate'].unique()
# Out:
# array([ 45., 255., 120.,  90., 190., 235., 150.,  25., 170.,  50.,  75.,
#        200., 100., 180.,  60., 225.,  30.,  35.,   3.,  65.,  70., 127.,
#        125., 205., 155., 145., 130., 140.,  15., 220., 160.,  80.,  55.,
#         nan])

# %%
pokemon_data['capture_rate'] = pd.to_numeric(pokemon_data.capture_rate, errors='coerce')

# %%
pokemon_data['capture_rate'].mean()
# Out:
# 97.94102564102565

# %%
pokemon_data[['capture_rate', 'Total_Attack']].head(20)
# Out:
#     capture_rate  Total_Attack
# 0           45.0           114
# 1           45.0           142
# 2           45.0           222
# 3           45.0           112
# 4           45.0           144
# 5           45.0           263
# 6           45.0            98
# 7           45.0           128
# 8           45.0           238
# 9          255.0            50
# 10         120.0            45
# 11          45.0           135
# 12         255.0            55
# 13         120.0            50
# 14          45.0           165
# 15         255.0            80
# 16         120.0           110
# 17          45.0           215
# 20         255.0            91
# 21          90.0           151

# %%
sucess = (pokemon_data['capture_rate']/pokemon_data['Total_Attack']).mean()
sucess
# Out:
# 0.928676888550774

# %%
pokemon_data.loc[pokemon_data['capture_rate'].isnull(), 'capture_rate'] = pokemon_data['Total_Attack']*0.92

# %%
pokemon_data['capture_rate'].unique()
# Out:
# array([ 45.        , 255.        , 120.        ,  90.        ,
#        190.        , 235.        , 150.        ,  25.        ,
#        170.        ,  50.        ,  75.        , 200.        ,
#        100.        , 180.        ,  60.        , 225.        ,
#         30.        ,  35.        ,   3.        ,  65.        ,
#         70.        , 127.        , 125.        , 205.        ,
#        155.        , 145.        , 130.        , 140.        ,
#         15.        , 220.        , 160.        ,  80.        ,
#         55.        , 185.73537771])

# %%
pokemon_data.loc[pokemon_data['percentage_male'].isnull(), 'percentage_male'] = 0.0

# %%
pokemon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 781 entries, 0 to 800
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          781 non-null    object
#  1   against_bug        781 non-null    float64
#  2   against_dark       781 non-null    float64
#  3   against_dragon     781 non-null    float64
#  4   against_electric   781 non-null    float64
#  5   against_fairy      781 non-null    float64
#  6   against_fight      781 non-null    float64
#  7   against_fire       781 non-null    float64
#  8   against_flying     781 non-null    float64
#  9   against_ghost      781 non-null    float64
#  10  against_grass      781 non-null    float64
#  11  against_ground     781 non-null    float64
#  12  against_ice        781 non-null    float64
#  13  against_normal     781 non-null    float64
#  14  against_poison     781 non-null    float64
# ...

# %%
pokemon_data.drop(columns=['percentage'], inplace=True)

# %%
pokemon_data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  sp_attack  sp_defense  speed  type1  \
# ...

# %%
import numpy as np

pokemon_data.to_csv('pokemon.csv',index=False)

# %%
help(np.savetxt)
# Out:
# Help on _ArrayFunctionDispatcher in module numpy:
#
# savetxt(fname, X, fmt='%.18e', delimiter=' ', newline='\n', header='', footer='', comments='# ', encoding=None)
#     Save an array to a text file.
#
#     Parameters
#     ----------
#     fname : filename or file handle
#         If the filename ends in ``.gz``, the file is automatically saved in
#         compressed gzip format.  `loadtxt` understands gzipped files
#         transparently.
#     X : 1D or 2D array_like
#         Data to be saved to a text file.
#     fmt : str or sequence of strs, optional
#         A single format (%10.5f), a sequence of formats, or a
#         multi-format string, e.g. 'Iteration %d -- %10.5f', in which
#         case `delimiter` is ignored. For complex `X`, the legal options
#         for `fmt` are:
#
#         * a single specifier, `fmt='%.4e'`, resulting in numbers formatted
#           like `' (%s+%sj)' % (fmt, fmt)`
# ...
